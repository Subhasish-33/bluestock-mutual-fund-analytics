# %% [markdown]
# # 01: Data Ingestion
#
# This notebook handles initial data ingestion from raw CSV files.

# %%
import pandas as pd
import os
import glob

# Load raw data
raw_path = "../data/raw/"
print(f"Loading data from {raw_path}")
