# %% [markdown]
# # 03: Exploratory Data Analysis
#
# This notebook performs exploratory data analysis on mutual fund data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# EDA operations
print("Exploratory Data Analysis")
