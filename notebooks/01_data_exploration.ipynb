# %% [markdown]
# # Data Exploration & Quality Check
#
# This notebook loads all CSV files from `data/raw/` and performs initial data quality checks.
#
# ## Process:
# 1. Load all CSV files
# 2. Inspect shape and data types
# 3. Check for null values
# 4. Display sample rows
# 5. Document anomalies

# %%
import pandas as pd
import os
import glob

# Load all CSV files from data/raw/
raw_path = "../data/raw/"
csv_files = glob.glob(raw_path + "*.csv")

datasets = {}
for f in csv_files:
    name = os.path.basename(f).replace(".csv", "")
    df = pd.read_csv(f)
    datasets[name] = df
    print(f"\n=== {name} ===")
    print("Shape:", df.shape)
    print("Dtypes:\n", df.dtypes)
    print(df.head(3))
    print("Nulls:\n", df.isnull().sum())
# Out:
# === 01_fund_master ===
# Shape: (40, 15)
# Dtypes:
#  amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object
#    amfi_code       fund_house                                 scheme_name  \
# 0     119551  SBI Mutual Fund   SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund    SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund  SBI Small Cap Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date             benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14         NIFTY 100 TRI
# ...

# %% [markdown]
# ## Data Quality Findings
#
# Document any anomalies discovered below:
#
# ### Null Values
# - *To be filled after loading data*
#
# ### Incorrect Data Types
# - *To be filled after loading data*
#
# ### Duplicate Rows
# - *To be filled after loading data*
#
# ### Other Issues
# - *To be filled after loading data*

# %%
# Check for duplicate rows in each dataset
print("\n=== DUPLICATE ROWS CHECK ===")
for name, df in datasets.items():
    duplicates = df.duplicated().sum()
    print(f"{name}: {duplicates} duplicate rows")
